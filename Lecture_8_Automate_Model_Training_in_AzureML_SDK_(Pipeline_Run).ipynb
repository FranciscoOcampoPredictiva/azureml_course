# %% [markdown]
# <a href="https://colab.research.google.com/github/FranciscoOcampoPredictiva/azureml_course/blob/main/Lecture_8_Automate_Model_Training_in_AzureML_SDK_(Pipeline_Run).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1) Installation and Setup

# %%
# Install azureml SDK package
! pip install -q azureml-sdk

# %%
# Import the class
from azureml.core import Workspace

# %%
# Access the workspace from config file and creating a workspace object
ws = Workspace.from_config(path='/content/config.json')

# %% [markdown]
# # 2) Running the Experiment

# %% [markdown]
# ## Creating the custom environment

# %%
from azureml.core import Environment
from azureml.core.environment import CondaDependencies

# %%
myenv = Environment(name="MyEnvironment")
myenv.python.user_managed_dependencies = False
myenv.docker.enabled = True
# Out:
# WARNING:azureml.core.environment:'enabled' is deprecated. Please use the azureml.core.runconfig.DockerConfiguration object with the 'use_docker' param instead.

# %%
# Creating the dependencies object
myenv_dep = CondaDependencies.create(conda_packages=['scikit-learn','pandas'],
                                     pip_packages=['azureml-sdk'])
myenv.python.conda_dependencies = myenv_dep

# %%
# Register the environment to workspace
myenv.register(ws)
# Out:
# {
#     "assetId": "azureml://locations/centralus/workspaces/b9dd55e8-c605-4c0b-b3ee-d4324e25cb2e/environments/MyEnvironment/versions/1",
#     "databricks": {
#         "eggLibraries": [],
#         "jarLibraries": [],
#         "mavenLibraries": [],
#         "pypiLibraries": [],
#         "rcranLibraries": []
#     },
#     "docker": {
#         "arguments": [],
#         "baseDockerfile": null,
#         "baseImage": "mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20230509.v1",
#         "baseImageRegistry": {
#             "address": null,
#             "password": null,
#             "registryIdentity": null,
#             "username": null
#         },
#         "buildContext": null,
#         "enabled": true,
#         "platform": {
#             "architecture": "amd64",
#             "os": "Linux"
#         },
#         "sharedVolumes": true,
#         "shmSize": null
#     },
#     "environmentVariables": {
#         "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#     },
#     "inferencingStackVersion": null,
#     "name": "MyEnvironment",
#     "python": {
#         "baseCondaEnvironment": null,
#         "condaDependencies": {
#             "channels": [
#                 "anaconda",
#                 "conda-forge"
#             ],
#             "dependencies": [
#                 "python=3.8.13",
#                 {
#                     "pip": [
#                         "azureml-sdk"
#                     ]
#                 },
#                 "scikit-learn",
#                 "pandas"
#             ],
#             "name": "project_environment"
#         },
#         "condaDependenciesFile": null,
#         "interpreterPath": "python",
#         "userManagedDependencies": false
#     },
#     "r": null,
#     "spark": {
#         "packages": [],
#         "precachePackages": true,
#         "repositories": []
#     },
#     "version": "1"
# }

# %% [markdown]
# ## Provision the compute cluster

# %%
# Specify the name of the cluster
cluster_name = 'Compute-Cluster'

# %%
# Import the classes
from azureml.core.compute import AmlCompute, ComputeTarget

# %%
# Configuration for the cluster
compute_config = AmlCompute.provisioning_configuration(vm_size='Standard_DS3_v2',
                                                       max_nodes=2)

# %%
# Create the compute cluster
compute_cluster = ComputeTarget.create(workspace=ws, name=cluster_name, provisioning_configuration=compute_config)
compute_cluster.wait_for_completion(show_output=True)
# Out:
# InProgress.
# SucceededProvisioning operation finished, operation "Succeeded"
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Run configuration steps

# %%
from azureml.core.runconfig import RunConfiguration
run_config = RunConfiguration()

run_config.target = compute_cluster
run_config.environment = myenv

# %% [markdown]
# ## Defining the pipeline steps

# %%
# Importing the classes
from azureml.pipeline.steps import PythonScriptStep
from azureml.pipeline.core import PipelineData

# Access the dataset
input_ds = ws.datasets.get('Churn-Modelling-Data-SDK')

# Pipeline data object
dataFolder = PipelineData(name='datafolder', datastore=ws.get_default_datastore())

# %%
# Step 1- Data Processing
dataPrep_step = PythonScriptStep(name='Data Processing',
                                 source_directory='.',
                                 script_name='data_processing_script.py',
                                 inputs=[input_ds.as_named_input('raw_data')],
                                 outputs=[dataFolder],
                                 runconfig=run_config,
                                 arguments=['--datafolder', dataFolder])

# %%
# Step 2 - Training the Model
train_step = PythonScriptStep(name='Model Training',
                                 source_directory='.',
                                 script_name='model_training_script.py',
                                 inputs=[dataFolder],
                                 runconfig=run_config,
                                 arguments=['--datafolder', dataFolder])

# %% [markdown]
# ## Configure and Build the Pipeline

# %%
steps = [dataPrep_step, train_step] # List of step names

from azureml.pipeline.core import Pipeline
new_pipeline = Pipeline(workspace=ws, steps=steps)

# %% [markdown]
# ## Creating experiment and running the pipeline

# %%
# Creating the experiment
from azureml.core import Experiment
new_experiment = Experiment(workspace=ws, name='PipelineExperiment')

# Submit the experiment run
new_pipeline_run = new_experiment.submit(new_pipeline)
new_pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step Data Processing [0fca5e8e][a186124a-dd4b-42fe-9858-86c8e86671a7], (This step will run and generate new outputs)Created step Model Training [ed53ccaf][55310afd-5c66-4e5f-84b7-e3c60ad5da06], (This step will run and generate new outputs)
#
# Submitted PipelineRun e03c172c-36a7-4762-9d59-5e3cb518083d
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/e03c172c-36a7-4762-9d59-5e3cb518083d?wsid=/subscriptions/8dd92a15-7a35-444a-99e8-7e44a3d0ae52/resourcegroups/azure-ml/workspaces/new_wrokspace&tid=20d3fbd0-4c6d-4dbc-b91c-aa00b337238c
# PipelineRunId: e03c172c-36a7-4762-9d59-5e3cb518083d
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/e03c172c-36a7-4762-9d59-5e3cb518083d?wsid=/subscriptions/8dd92a15-7a35-444a-99e8-7e44a3d0ae52/resourcegroups/azure-ml/workspaces/new_wrokspace&tid=20d3fbd0-4c6d-4dbc-b91c-aa00b337238c
# PipelineRun Status: Running
#
#
# StepRunId: f0008e28-da6c-4bfc-b931-56264c048dee
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/f0008e28-da6c-4bfc-b931-56264c048dee?wsid=/subscriptions/8dd92a15-7a35-444a-99e8-7e44a3d0ae52/resourcegroups/azure-ml/workspaces/new_wrokspace&tid=20d3fbd0-4c6d-4dbc-b91c-aa00b337238c
# StepRun( Data Processing ) Status: NotStarted
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2023/06/25 22:29:52 Downloading source code...
# 2023/06/25 22:29:53 Finished downloading source code
# 2023/06/25 22:29:53 Creating Docker network: acb_default_network, driver: 'bridge'
# 2023/06/25 22:29:53 Successfully set up Docker network: acb_default_network
# 2023/06/25 22:29:53 Setting up Docker configuration...
# 2023/06/25 22:29:54 Successfully set up Docker configuration
# 2023/06/25 22:29:54 Logging in to registry: b9dd55e8c6054c0bb3eed4324e25cb2e.azurecr.io
# 2023/06/25 22:29:54 Successfully logged into b9dd55e8c6054c0bb3eed4324e25cb2e.azurecr.io
# 2023/06/25 22:29:55 Volume source scriptsFromEms successfully created
# 2023/06/25 22:29:55 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2023/06/25 22:29:55 Scanning for dependencies...
# 2023/06/25 22:29:55 Successfully scanned dependencies
# 2023/06/25 22:29:55 Launching container with name: acb_step_0
# Sending build context to Docker daemon  77.31kB
#
# Step 1/21 : FROM mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20230509.v1@sha256:21a5aff01e75574d94cd25802026a9ac5be1936dc2afe2973537f2c47abd4bc5
# mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20230509.v1@sha256:21a5aff01e75574d94cd25802026a9ac5be1936dc2afe2973537f2c47abd4bc5: Pulling from azureml/openmpi4.1.0-ubuntu20.04
# 99803d4b97f3: Already exists
# 70360b991f81: Pulling fs layer
# be3bbb711686: Pulling fs layer
# a4af251bcb46: Pulling fs layer
# 38baff24aff5: Pulling fs layer
# 050145919e6a: Pulling fs layer
# 6b155a65e6c0: Pulling fs layer
# 7e0748d6ff6c: Pulling fs layer
# 430355abe702: Pulling fs layer
# 06e63bb8b14a: Pulling fs layer
# 6b155a65e6c0: Waiting
# 7e0748d6ff6c: Waiting
# 430355abe702: Waiting
# 06e63bb8b14a: Waiting
# 38baff24aff5: Waiting
# 050145919e6a: Waiting
# be3bbb711686: Verifying Checksum
# be3bbb711686: Download complete
# a4af251bcb46: Verifying Checksum
# a4af251bcb46: Download complete
# 38baff24aff5: Verifying Checksum
# 38baff24aff5: Download complete
# 6b155a65e6c0: Verifying Checksum
# 6b155a65e6c0: Download complete
# 050145919e6a: Verifying Checksum
# 050145919e6a: Download complete
# 430355abe702: Verifying Checksum
# 430355abe702: Download complete
# 7e0748d6ff6c: Verifying Checksum
# 7e0748d6ff6c: Download complete
# 06e63bb8b14a: Verifying Checksum
# 06e63bb8b14a: Download complete
# 70360b991f81: Download complete
# 70360b991f81: Pull complete
# StepRun( Data Processing ) Status: Running
# be3bbb711686: Pull complete
# a4af251bcb46: Pull complete
# 38baff24aff5: Pull complete
# 050145919e6a: Pull complete
# 6b155a65e6c0: Pull complete
# 7e0748d6ff6c: Pull complete
# 430355abe702: Pull complete
# 06e63bb8b14a: Pull complete
# Digest: sha256:21a5aff01e75574d94cd25802026a9ac5be1936dc2afe2973537f2c47abd4bc5
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20230509.v1@sha256:21a5aff01e75574d94cd25802026a9ac5be1936dc2afe2973537f2c47abd4bc5
#  ---> cc73fcec3204
# Step 2/21 : USER root
#  ---> Running in 20f743de71d1
# Removing intermediate container 20f743de71d1
#  ---> 20ad1c818aaf
# Step 3/21 : RUN mkdir -p $HOME/.cache
#  ---> Running in 91b411a3adb3
# Removing intermediate container 91b411a3adb3
#  ---> c24b9eccb9c8
# Step 4/21 : WORKDIR /
#  ---> Running in 14bcf2547fe8
# Removing intermediate container 14bcf2547fe8
#  ---> 185640a1075d
# Step 5/21 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 04170bc4b7ac
# Step 6/21 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 9c7a406e52c2
# Removing intermediate container 9c7a406e52c2
#  ---> 950d9eba05b0
# Step 7/21 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> d1342b8e30f6
# Step 8/21 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in dddeee99a23b
# Retrieving notices: ...working... done
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.5.0
#
#
#
# ca-certificates-2023 | 127 KB    |            |   0%
#
# _openmp_mutex-5.1    | 20 KB     |            |   0%
#
#
# zlib-1.2.13          | 125 KB    |            |   0%
#
#
#
# mkl-2021.4.0         | 219.1 MB  |            |   0%
#
#
#
#
# wheel-0.37.1         | 31 KB     |            |   0%
#
#
#
#
#
# libgomp-11.2.0       | 560 KB    |            |   0%
#
#
#
#
#
#
# joblib-1.1.1         | 406 KB    |            |   0%
#
#
#
#
#
#
#
# libstdcxx-ng-11.2.0  | 6.1 MB    |            |   0%
#
#
#
#
#
#
#
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
#
#
#
#
#
#
#
#
#
# mkl_random-1.2.2     | 341 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# libgfortran-ng-11.2. | 19 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# numexpr-2.8.4        | 134 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# readline-8.2         | 457 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ncurses-6.4          | 1.1 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.12            | 3.3 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# six-1.16.0           | 19 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-22.0       | 63 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2022.12.7    | 152 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-dateutil-2.8. | 241 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# ca-certificates-2023 | 127 KB    | #2         |  13%
#
# _openmp_mutex-5.1    | 20 KB     | #######8   |  79%
#
#
#
#
# wheel-0.37.1         | 31 KB     | #####1     |  52%
#
#
# zlib-1.2.13          | 125 KB    | #2         |  13%
#
#
#
# mkl-2021.4.0         | 219.1 MB  |            |   0%
#
# _openmp_mutex-5.1    | 20 KB     | ########## | 100%
#
#
#
#
#
# libgomp-11.2.0       | 560 KB    | 2          |   3%
#
#
#
#
# wheel-0.37.1         | 31 KB     | ########## | 100%
#
#
#
#
#
#
# joblib-1.1.1         | 406 KB    | 3          |   4%
#
#
#
#
#
#
#
# libstdcxx-ng-11.2.0  | 6.1 MB    |            |   0%
# ca-certificates-2023 | 127 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
#
# zlib-1.2.13          | 125 KB    | ########## | 100%
#
#
#
# mkl-2021.4.0         | 219.1 MB  |            |   0%
#
#
#
#
#
#
#
#
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
#
#
#
#
#
#
# libstdcxx-ng-11.2.0  | 6.1 MB    | 5          |   6%
#
#
#
#
#
#
#
#
#
#
# libgfortran-ng-11.2. | 19 KB     | ########2  |  82%
#
#
#
#
#
#
#
#
#
# mkl_random-1.2.2     | 341 KB    | 4          |   5%
#
#
#
#
#
#
# joblib-1.1.1         | 406 KB    | #########  |  91%
#
#
#
# mkl-2021.4.0         | 219.1 MB  |            |   0%
#
#
#
#
#
# libgomp-11.2.0       | 560 KB    | ########## | 100%
#
#
#
#
#
# libgomp-11.2.0       | 560 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# libgfortran-ng-11.2. | 19 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# readline-8.2         | 457 KB    | 3          |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ncurses-6.4          | 1.1 MB    | 1          |   1%
#
#
#
#
#
#
#
# libstdcxx-ng-11.2.0  | 6.1 MB    | #7         |  18%
#
#
#
#
#
#
#
#
#
#
#
# numexpr-2.8.4        | 134 KB    | #1         |  12%
#
#
#
# mkl-2021.4.0         | 219.1 MB  |            |   1%
#
#
#
#
#
#
#
#
#
# mkl_random-1.2.2     | 341 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# mkl_random-1.2.2     | 341 KB    | ########## | 100%
#
#
#
#
#
#
#
# libstdcxx-ng-11.2.0  | 6.1 MB    | ##4        |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.12            | 3.3 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# six-1.16.0           | 19 KB     | ########5  |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ncurses-6.4          | 1.1 MB    | #####2     |  52%
#
#
#
# mkl-2021.4.0         | 219.1 MB  |            |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-22.0       | 63 KB     | ##5        |  25%
#
#
#
#
#
#
# joblib-1.1.1         | 406 KB    | ########## | 100%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 1          |   1%
#
#
#
#
#
#
#
# libstdcxx-ng-11.2.0  | 6.1 MB    | ####7      |  48%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.12            | 3.3 MB    | ####       |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-dateutil-2.8. | 241 KB    | 6          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2022.12.7    | 152 KB    | #          |  11%
#
#
#
#
#
#
#
#
#
#
#
#
# readline-8.2         | 457 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# readline-8.2         | 457 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# numexpr-2.8.4        | 134 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# numexpr-2.8.4        | 134 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# six-1.16.0           | 19 KB     | ########## | 100%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 1          |   2%
#
#
#
#
#
#
#
# libstdcxx-ng-11.2.0  | 6.1 MB    | #####7     |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.12            | 3.3 MB    | #####8     |  58%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 2          |   2%
#
#
#
#
#
#
#
# libstdcxx-ng-11.2.0  | 6.1 MB    | #######9   |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.12            | 3.3 MB    | #########8 |  99%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 3          |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 3          |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 4          |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 5          |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
# ncurses-6.4          | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ncurses-6.4          | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-22.0       | 63 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-22.0       | 63 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2022.12.7    | 152 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2022.12.7    | 152 KB    | ########## | 100%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 5          |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-dateutil-2.8. | 241 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-dateutil-2.8. | 241 KB    | ########## | 100%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 6          |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.12            | 3.3 MB    | ########## | 100%
#
#
#
#
#
#
#
# libstdcxx-ng-11.2.0  | 6.1 MB    | ########## | 100%
#
#
#
#
#
#
#
# libstdcxx-ng-11.2.0  | 6.1 MB    | ########## | 100%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 6          |   7%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 7          |   7%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 8          |   8%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 8          |   8%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 9          |   9%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | 9          |  10%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #          |  10%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #          |  11%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #1         |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #2         |  12%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #2         |  13%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #3         |  13%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #3         |  13%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #4         |  14%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #5         |  15%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #6         |  17%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #7         |  17%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #7         |  18%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #8         |  19%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #9         |  19%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##         |  21%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##2        |  22%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ##6        |  27%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###        |  30%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ###4       |  35%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####       |  41%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ####7      |  48%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #####4     |  54%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ######1    |  61%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ######7    |  68%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #######4   |  75%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ########1  |  82%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ########8  |  88%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | #########3 |  94%
#
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ########## | 100%
#
#
#
# mkl-2021.4.0         | 219.1 MB  | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.gt06ph2l.requirements.txt', '--exists-action=b']
# Pip subprocess output:
# Collecting azureml-sdk
#   Downloading azureml_sdk-1.51.0-py3-none-any.whl (2.7 kB)
# Collecting azureml-core~=1.51.0
#   Downloading azureml_core-1.51.0.post1-py3-none-any.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 33.2 MB/s eta 0:00:00
# Collecting azureml-dataset-runtime[fuse]~=1.51.0
#   Downloading azureml_dataset_runtime-1.51.0-py3-none-any.whl (2.3 kB)
# Collecting azureml-pipeline~=1.51.0
#   Downloading azureml_pipeline-1.51.0-py3-none-any.whl (2.4 kB)
# Collecting azureml-train-core~=1.51.0
#   Downloading azureml_train_core-1.51.0-py3-none-any.whl (8.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 102.2 MB/s eta 0:00:00
# Collecting azureml-train-automl-client~=1.51.0
#   Downloading azureml_train_automl_client-1.51.0.post1-py3-none-any.whl (136 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.5/136.5 kB 29.4 MB/s eta 0:00:00
# Collecting humanfriendly<11.0,>=4.7
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 17.2 MB/s eta 0:00:00
# Collecting azure-mgmt-resource<=22.0.0,>=15.0.0
#   Downloading azure_mgmt_resource-22.0.0-py3-none-any.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 122.3 MB/s eta 0:00:00
# Collecting docker<7.0.0
#   Downloading docker-6.1.3-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 kB 34.3 MB/s eta 0:00:00
# Collecting requests[socks]<3.0.0,>=2.19.1
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 14.8 MB/s eta 0:00:00
# Collecting azure-core<2.0.0
#   Downloading azure_core-1.27.1-py3-none-any.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.5/174.5 kB 38.1 MB/s eta 0:00:00
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,>=41
#   Downloading cryptography-41.0.1-cp37-abi3-manylinux_2_28_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 130.6 MB/s eta 0:00:00
# Collecting jsonpickle<4.0.0
#   Downloading jsonpickle-3.0.1-py2.py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 1.3 MB/s eta 0:00:00
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting msrestazure<=0.6.4,>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 8.9 MB/s eta 0:00:00
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.3-py3-none-any.whl (15 kB)
# Collecting urllib3<2.0.0,>=1.23
#   Downloading urllib3-1.26.16-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.1/143.1 kB 30.0 MB/s eta 0:00:00
# Collecting jmespath<2.0.0
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting argcomplete<3
#   Downloading argcomplete-2.1.2-py3-none-any.whl (37 kB)
# Collecting azure-mgmt-keyvault<11.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-10.2.2-py3-none-any.whl (780 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.2/780.2 kB 94.8 MB/s eta 0:00:00
# Collecting msal-extensions<=1.0.0,>=0.3.0
#   Downloading msal_extensions-1.0.0-py2.py3-none-any.whl (19 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in /azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99/lib/python3.8/site-packages (from azureml-core~=1.51.0->azureml-sdk->-r /azureml-environment-setup/condaenv.gt06ph2l.requirements.txt (line 1)) (2.8.2)
# Collecting pyopenssl<24.0.0
#   Downloading pyOpenSSL-23.2.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 12.8 MB/s eta 0:00:00
# Collecting pkginfo
#   Downloading pkginfo-1.9.6-py3-none-any.whl (30 kB)
# Requirement already satisfied: pytz in /azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99/lib/python3.8/site-packages (from azureml-core~=1.51.0->azureml-sdk->-r /azureml-environment-setup/condaenv.gt06ph2l.requirements.txt (line 1)) (2022.7)
# Collecting msrest<=0.7.1,>=0.5.1
#   Downloading msrest-0.7.1-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 20.0 MB/s eta 0:00:00
# Collecting ndg-httpsclient<=0.5.1
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.7.0-py3-none-any.whl (22 kB)
# Collecting azure-mgmt-authorization<4,>=0.40.0
#   Downloading azure_mgmt_authorization-3.0.0-py3-none-any.whl (965 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.9/965.9 kB 69.1 MB/s eta 0:00:00
# Collecting paramiko<4.0.0,>=2.0.8
#   Downloading paramiko-3.2.0-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.2/224.2 kB 51.9 MB/s eta 0:00:00
# Collecting msal<2.0.0,>=1.15.0
#   Downloading msal-1.22.0-py2.py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 23.0 MB/s eta 0:00:00
# Collecting contextlib2<22.0.0
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting adal<=1.2.7,>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 3.9 MB/s eta 0:00:00
# Collecting knack~=0.10.0
#   Downloading knack-0.10.1-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 14.8 MB/s eta 0:00:00
# Collecting azure-mgmt-storage<=21.0.0,>=16.0.0
#   Downloading azure_mgmt_storage-21.0.0-py3-none-any.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 111.8 MB/s eta 0:00:00
# Collecting azure-mgmt-containerregistry<11,>=8.2.0
#   Downloading azure_mgmt_containerregistry-10.1.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 109.0 MB/s eta 0:00:00
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.4/141.4 kB 30.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging<=23.0,>=20.0 in /azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99/lib/python3.8/site-packages (from azureml-core~=1.51.0->azureml-sdk->-r /azureml-environment-setup/condaenv.gt06ph2l.requirements.txt (line 1)) (22.0)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.11.1-py3-none-any.whl (29 kB)
# Collecting azureml-dataprep<4.11.0a,>=4.10.0a
#   Downloading azureml_dataprep-4.10.8-py3-none-any.whl (38.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 66.7 MB/s eta 0:00:00
# Collecting pyarrow<=9.0.0,>=0.17.0
#   Downloading pyarrow-9.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 73.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy!=1.19.3,<1.24 in /azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99/lib/python3.8/site-packages (from azureml-dataset-runtime[fuse]~=1.51.0->azureml-sdk->-r /azureml-environment-setup/condaenv.gt06ph2l.requirements.txt (line 1)) (1.23.5)
# Collecting fusepy<4.0.0,>=3.0.1
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting azureml-pipeline-core~=1.51.0
#   Downloading azureml_pipeline_core-1.51.0-py3-none-any.whl (313 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.1/313.1 kB 48.9 MB/s eta 0:00:00
# Collecting azureml-pipeline-steps~=1.51.0
#   Downloading azureml_pipeline_steps-1.51.0-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.5/69.5 kB 16.4 MB/s eta 0:00:00
# Collecting azureml-automl-core~=1.51.0
#   Downloading azureml_automl_core-1.51.0.post1-py3-none-any.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.2/247.2 kB 56.5 MB/s eta 0:00:00
# Collecting azureml-telemetry~=1.51.0
#   Downloading azureml_telemetry-1.51.0-py3-none-any.whl (30 kB)
# Collecting azureml-train-restclients-hyperdrive~=1.51.0
#   Downloading azureml_train_restclients_hyperdrive-1.51.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: six>=1.11.0 in /azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99/lib/python3.8/site-packages (from azure-core<2.0.0->azureml-core~=1.51.0->azureml-sdk->-r /azureml-environment-setup/condaenv.gt06ph2l.requirements.txt (line 1)) (1.16.0)
# Collecting typing-extensions>=4.3.0
#   Downloading typing_extensions-4.6.3-py3-none-any.whl (31 kB)
# Collecting azure-mgmt-core<2.0.0,>=1.3.2
#   Downloading azure_mgmt_core-1.4.0-py3-none-any.whl (27 kB)
# Collecting isodate<1.0.0,>=0.6.1
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 8.3 MB/s eta 0:00:00
# Collecting dotnetcore2<4.0.0,>=3.0.0
#   Downloading dotnetcore2-3.1.23-py3-none-manylinux1_x86_64.whl (31.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.1/31.1 MB 63.2 MB/s eta 0:00:00
# Collecting azureml-dataprep-rslex~=2.17.12dev0
#   Downloading azureml_dataprep_rslex-2.17.12-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 61.9 MB/s eta 0:00:00
# Collecting jsonschema
#   Downloading jsonschema-4.17.3-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 kB 18.6 MB/s eta 0:00:00
# Collecting cloudpickle<3.0.0,>=1.1.0
#   Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Collecting azure-identity>=1.7.0
#   Downloading azure_identity-1.13.0-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.6/151.6 kB 39.2 MB/s eta 0:00:00
# Collecting pyyaml<7.0.0,>=5.1.0
#   Downloading PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 701.2/701.2 kB 99.1 MB/s eta 0:00:00
# Collecting azureml-dataprep-native<39.0.0,>=38.0.0
#   Downloading azureml_dataprep_native-38.0.0-cp38-cp38-manylinux1_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 112.0 MB/s eta 0:00:00
# Collecting applicationinsights
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 15.1 MB/s eta 0:00:00
# Collecting cffi>=1.12
#   Downloading cffi-1.15.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.7/442.7 kB 31.6 MB/s eta 0:00:00
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.6.1-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 3.9 MB/s eta 0:00:00
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting pygments
#   Downloading Pygments-2.15.1-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 91.3 MB/s eta 0:00:00
# Collecting portalocker<3,>=1.0
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99/lib/python3.8/site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core~=1.51.0->azureml-sdk->-r /azureml-environment-setup/condaenv.gt06ph2l.requirements.txt (line 1)) (2022.12.7)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.9/83.9 kB 15.5 MB/s eta 0:00:00
# Collecting pynacl>=1.5
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 82.3 MB/s eta 0:00:00
# Collecting bcrypt>=3.2
#   Downloading bcrypt-4.0.1-cp36-abi3-manylinux_2_28_x86_64.whl (593 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.7/593.7 kB 82.3 MB/s eta 0:00:00
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (195 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.9/195.9 kB 42.4 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 13.8 MB/s eta 0:00:00
# Collecting PySocks!=1.5.7,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.8.0-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 10.3 MB/s eta 0:00:00
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 27.7 MB/s eta 0:00:00
# Collecting distro>=1.2.0
#   Downloading distro-1.8.0-py3-none-any.whl (20 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 31.2 MB/s eta 0:00:00
# Collecting attrs>=17.4.0
#   Downloading attrs-23.1.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 14.0 MB/s eta 0:00:00
# Collecting pkgutil-resolve-name>=1.3.10
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Downloading pyrsistent-0.19.3-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 11.3 MB/s eta 0:00:00
# Collecting importlib-resources>=1.4.0
#   Downloading importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Collecting zipp>=3.1.0
#   Downloading zipp-3.15.0-py3-none-any.whl (6.8 kB)
# Building wheels for collected packages: fusepy
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10486 sha256=8ccef22032b6b28b48fcc260bcba600831e079e40864cb08dc27e5cf6486e2a4
#   Stored in directory: /root/.cache/pip/wheels/db/01/ee/105147547cf0ecd1031b26901757e1f17c98902c8cc7bcaa47
# Successfully built fusepy
# Installing collected packages: fusepy, backports.weakref, azureml-dataprep-rslex, azureml-dataprep-native, azure-common, applicationinsights, zipp, websocket-client, urllib3, typing-extensions, tabulate, pyyaml, PySocks, pyrsistent, PyJWT, pygments, pycparser, pyasn1, pyarrow, portalocker, pkgutil-resolve-name, pkginfo, pathspec, oauthlib, jsonpickle, jmespath, jeepney, isodate, idna, humanfriendly, distro, contextlib2, cloudpickle, charset-normalizer, bcrypt, backports.tempfile, attrs, argcomplete, requests, knack, importlib-resources, dotnetcore2, cffi, requests-oauthlib, pynacl, jsonschema, docker, cryptography, azure-core, SecretStorage, pyopenssl, paramiko, msrest, azure-mgmt-core, adal, ndg-httpsclient, msrestazure, msal, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, msal-extensions, azureml-train-restclients-hyperdrive, azure-graphrbac, azureml-core, azure-identity, azureml-telemetry, azureml-pipeline-core, azureml-dataprep, azureml-train-core, azureml-dataset-runtime, azureml-automl-core, azureml-train-automl-client, azureml-pipeline-steps, azureml-pipeline, azureml-sdk
# Successfully installed PyJWT-2.7.0 PySocks-1.7.1 SecretStorage-3.3.3 adal-1.2.7 applicationinsights-0.11.10 argcomplete-2.1.2 attrs-23.1.0 azure-common-1.1.28 azure-core-1.27.1 azure-graphrbac-0.61.1 azure-identity-1.13.0 azure-mgmt-authorization-3.0.0 azure-mgmt-containerregistry-10.1.0 azure-mgmt-core-1.4.0 azure-mgmt-keyvault-10.2.2 azure-mgmt-resource-22.0.0 azure-mgmt-storage-21.0.0 azureml-automl-core-1.51.0.post1 azureml-core-1.51.0.post1 azureml-dataprep-4.10.8 azureml-dataprep-native-38.0.0 azureml-dataprep-rslex-2.17.12 azureml-dataset-runtime-1.51.0 azureml-pipeline-1.51.0 azureml-pipeline-core-1.51.0 azureml-pipeline-steps-1.51.0 azureml-sdk-1.51.0 azureml-telemetry-1.51.0 azureml-train-automl-client-1.51.0.post1 azureml-train-core-1.51.0 azureml-train-restclients-hyperdrive-1.51.0 backports.tempfile-1.0 backports.weakref-1.0.post1 bcrypt-4.0.1 cffi-1.15.1 charset-normalizer-3.1.0 cloudpickle-2.2.1 contextlib2-21.6.0 cryptography-41.0.1 distro-1.8.0 docker-6.1.3 dotnetcore2-3.1.23 fusepy-3.0.1 humanfriendly-10.0 idna-3.4 importlib-resources-5.12.0 isodate-0.6.1 jeepney-0.8.0 jmespath-1.0.1 jsonpickle-3.0.1 jsonschema-4.17.3 knack-0.10.1 msal-1.22.0 msal-extensions-1.0.0 msrest-0.7.1 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.2.2 paramiko-3.2.0 pathspec-0.11.1 pkginfo-1.9.6 pkgutil-resolve-name-1.3.10 portalocker-2.7.0 pyarrow-9.0.0 pyasn1-0.5.0 pycparser-2.21 pygments-2.15.1 pynacl-1.5.0 pyopenssl-23.2.0 pyrsistent-0.19.3 pyyaml-6.0 requests-2.31.0 requests-oauthlib-1.3.1 tabulate-0.9.0 typing-extensions-4.6.3 urllib3-1.26.16 websocket-client-1.6.1 zipp-3.15.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Removing intermediate container dddeee99a23b
#  ---> 6f51d912ab30
# Step 9/21 : ENV PATH /azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99/bin:$PATH
#  ---> Running in a5587c57cce5
# Removing intermediate container a5587c57cce5
#  ---> 1845c90d1fa3
# Step 10/21 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> 96964413552c
# Step 11/21 : RUN echo "Copying environment context"
#  ---> Running in f3a8bdc55237
# Copying environment context
# Removing intermediate container f3a8bdc55237
#  ---> 89cc0a4906f8
# Step 12/21 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 2fc53b3194e1
# Step 13/21 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99
#  ---> Running in 05784630c1e3
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 05784630c1e3
#  ---> a9b6496bde3c
# Step 14/21 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99
#  ---> Running in 069e4e59a6d6
# Removing intermediate container 069e4e59a6d6
#  ---> 80273dd157db
# Step 15/21 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99/lib:$LD_LIBRARY_PATH
#  ---> Running in 65618e12346e
# Removing intermediate container 65618e12346e
#  ---> fe6deb3c1396
# Step 16/21 : ENV CONDA_DEFAULT_ENV=azureml_9213d7cc2cbd0e159e0a1ad4c5452b99 CONDA_PREFIX=/azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99
#  ---> Running in bc57797a3a62
# Removing intermediate container bc57797a3a62
#  ---> 16a1882a2459
# Step 17/21 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> bc43fb067969
# Step 18/21 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 11045fe68c23
# Removing intermediate container 11045fe68c23
#  ---> 11237633993e
# Step 19/21 : RUN rm -rf azureml-environment-setup
#  ---> Running in 11713008b2d4
# Removing intermediate container 11713008b2d4
#  ---> 3be1cc8a4f7f
# Step 20/21 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 30f0db5099b6
# Removing intermediate container 30f0db5099b6
#  ---> 91c1bbeccaee
# Step 21/21 : CMD ["bash"]
#  ---> Running in df533d1d5ffc
# Removing intermediate container df533d1d5ffc
#  ---> e7ab683ed86f
# Successfully built e7ab683ed86f
# Successfully tagged b9dd55e8c6054c0bb3eed4324e25cb2e.azurecr.io/azureml/azureml_c7e5851c38824cac78da4a5ad976968e:latest
# Successfully tagged b9dd55e8c6054c0bb3eed4324e25cb2e.azurecr.io/azureml/azureml_c7e5851c38824cac78da4a5ad976968e:1
# 2023/06/25 22:37:43 Successfully executed container: acb_step_0
# 2023/06/25 22:37:43 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2023/06/25 22:37:43 Pushing image: b9dd55e8c6054c0bb3eed4324e25cb2e.azurecr.io/azureml/azureml_c7e5851c38824cac78da4a5ad976968e:1, attempt 1
# The push refers to repository [b9dd55e8c6054c0bb3eed4324e25cb2e.azurecr.io/azureml/azureml_c7e5851c38824cac78da4a5ad976968e]
# b3acac4845e2: Preparing
# 92ee6d042e77: Preparing
# 292fccdace70: Preparing
# da2c76785357: Preparing
# 8e14c97010f0: Preparing
# c30b2da7e262: Preparing
# c2b11fae47ce: Preparing
# 264c46f6ff24: Preparing
# b39ffc92581a: Preparing
# 3d2b32357ac5: Preparing
# 80092de86700: Preparing
# bfe26693c1b8: Preparing
# f13c2a922198: Preparing
# 8876548890be: Preparing
# 47fdfc870393: Preparing
# 9f0a222a3c0b: Preparing
# 3a9464fdea5f: Preparing
# c2159661d617: Preparing
# 6f37ca73c74f: Preparing
# c30b2da7e262: Waiting
# c2b11fae47ce: Waiting
# 264c46f6ff24: Waiting
# b39ffc92581a: Waiting
# 3d2b32357ac5: Waiting
# 9f0a222a3c0b: Waiting
# 3a9464fdea5f: Waiting
# c2159661d617: Waiting
# 6f37ca73c74f: Waiting
# 80092de86700: Waiting
# bfe26693c1b8: Waiting
# f13c2a922198: Waiting
# 47fdfc870393: Waiting
# 8876548890be: Waiting
# da2c76785357: Pushed
# 92ee6d042e77: Pushed
# b3acac4845e2: Pushed
# 8e14c97010f0: Pushed
# c2b11fae47ce: Pushed
# 292fccdace70: Pushed
# b39ffc92581a: Pushed
# 264c46f6ff24: Pushed
# 3d2b32357ac5: Pushed
# 80092de86700: Pushed
# 47fdfc870393: Pushed
# f13c2a922198: Pushed
# bfe26693c1b8: Pushed
# 3a9464fdea5f: Pushed
# 9f0a222a3c0b: Pushed
# 6f37ca73c74f: Pushed
# 8876548890be: Pushed
#
# c2159661d617: Pushed
# c30b2da7e262: Pushed
# 1: digest: sha256:418b704165f089a265b2b31a99cef228fb1fb521919795dbbffb3b2f465d7408 size: 4305
# 2023/06/25 22:39:15 Successfully pushed image: b9dd55e8c6054c0bb3eed4324e25cb2e.azurecr.io/azureml/azureml_c7e5851c38824cac78da4a5ad976968e:1
# 2023/06/25 22:39:15 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2023/06/25 22:39:15 Pushing image: b9dd55e8c6054c0bb3eed4324e25cb2e.azurecr.io/azureml/azureml_c7e5851c38824cac78da4a5ad976968e:latest, attempt 1
# The push refers to repository [b9dd55e8c6054c0bb3eed4324e25cb2e.azurecr.io/azureml/azureml_c7e5851c38824cac78da4a5ad976968e]
# b3acac4845e2: Preparing
# 92ee6d042e77: Preparing
# 292fccdace70: Preparing
# da2c76785357: Preparing
# 8e14c97010f0: Preparing
# c30b2da7e262: Preparing
# c2b11fae47ce: Preparing
# 264c46f6ff24: Preparing
# b39ffc92581a: Preparing
# 3d2b32357ac5: Preparing
# 80092de86700: Preparing
# bfe26693c1b8: Preparing
# f13c2a922198: Preparing
# 8876548890be: Preparing
# 47fdfc870393: Preparing
# 9f0a222a3c0b: Preparing
# 3a9464fdea5f: Preparing
# c2159661d617: Preparing
# 6f37ca73c74f: Preparing
# c30b2da7e262: Waiting
# c2b11fae47ce: Waiting
# 264c46f6ff24: Waiting
# b39ffc92581a: Waiting
# 3d2b32357ac5: Waiting
# 80092de86700: Waiting
# bfe26693c1b8: Waiting
# f13c2a922198: Waiting
# 8876548890be: Waiting
# 47fdfc870393: Waiting
# 9f0a222a3c0b: Waiting
# 3a9464fdea5f: Waiting
# c2159661d617: Waiting
# 6f37ca73c74f: Waiting
# 292fccdace70: Layer already exists
# c30b2da7e262: Layer already exists
# c2b11fae47ce: Layer already exists
# 264c46f6ff24: Layer already exists
# b39ffc92581a: Layer already exists
# 3d2b32357ac5: Layer already exists
# 80092de86700: Layer already exists
# bfe26693c1b8: Layer already exists
# f13c2a922198: Layer already exists
# 8876548890be: Layer already exists
# 47fdfc870393: Layer already exists
# 9f0a222a3c0b: Layer already exists
# 3a9464fdea5f: Layer already exists
# c2159661d617: Layer already exists
# b3acac4845e2: Layer already exists
# da2c76785357: Layer already exists
# 92ee6d042e77: Layer already exists
# 8e14c97010f0: Layer already exists
# 6f37ca73c74f: Layer already exists
# latest: digest: sha256:418b704165f089a265b2b31a99cef228fb1fb521919795dbbffb3b2f465d7408 size: 4305
# 2023/06/25 22:39:22 Successfully pushed image: b9dd55e8c6054c0bb3eed4324e25cb2e.azurecr.io/azureml/azureml_c7e5851c38824cac78da4a5ad976968e:latest
# 2023/06/25 22:39:22 Executing step ID: acb_step_3. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2023/06/25 22:39:22 Launching container with name: acb_step_3
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment dependencies
# 2023/06/25 22:39:24 Successfully executed container: acb_step_3
# 2023/06/25 22:39:24 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 467.769153)
# 2023/06/25 22:39:24 Populating digests for step ID: acb_step_0...
# 2023/06/25 22:39:25 Successfully populated digests for step ID: acb_step_0
# 2023/06/25 22:39:25 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 92.350910)
# 2023/06/25 22:39:25 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 6.764383)
# 2023/06/25 22:39:25 Step ID: acb_step_3 marked as successful (elapsed time in seconds: 2.376580)
# 2023/06/25 22:39:25 The following dependencies were found:
# 2023/06/25 22:39:25
# - image:
#     registry: b9dd55e8c6054c0bb3eed4324e25cb2e.azurecr.io
#     repository: azureml/azureml_c7e5851c38824cac78da4a5ad976968e
#     tag: latest
#     digest: sha256:418b704165f089a265b2b31a99cef228fb1fb521919795dbbffb3b2f465d7408
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi4.1.0-ubuntu20.04
#     tag: 20230509.v1
#     digest: sha256:21a5aff01e75574d94cd25802026a9ac5be1936dc2afe2973537f2c47abd4bc5
#   git: {}
# - image:
#     registry: b9dd55e8c6054c0bb3eed4324e25cb2e.azurecr.io
#     repository: azureml/azureml_c7e5851c38824cac78da4a5ad976968e
#     tag: "1"
#     digest: sha256:418b704165f089a265b2b31a99cef228fb1fb521919795dbbffb3b2f465d7408
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi4.1.0-ubuntu20.04
#     tag: 20230509.v1
#     digest: sha256:21a5aff01e75574d94cd25802026a9ac5be1936dc2afe2973537f2c47abd4bc5
#   git: {}
#
#
# Run ID: cj1 was successful after 9m34s
#
# StepRun(Data Processing) Execution Summary
# ===========================================
# StepRun( Data Processing ) Status: Finished
# {'runId': 'f0008e28-da6c-4bfc-b931-56264c048dee', 'target': 'Compute-Cluster', 'status': 'Completed', 'startTimeUtc': '2023-06-25T22:41:55.371741Z', 'endTimeUtc': '2023-06-25T22:42:50.712582Z', 'services': {}, 'properties': {'ContentSnapshotId': 'dd8502be-929b-49c0-86ce-cc9ab504b413', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'a186124a-dd4b-42fe-9858-86c8e86671a7', 'azureml.moduleName': 'Data Processing', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '0fca5e8e', 'azureml.pipelinerunid': 'e03c172c-36a7-4762-9d59-5e3cb518083d', 'azureml.pipeline': 'e03c172c-36a7-4762-9d59-5e3cb518083d', 'azureml.rootpipelinerunid': 'e03c172c-36a7-4762-9d59-5e3cb518083d', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'amlctrain', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '23f4c02f-90a5-4f21-9470-ed8583e97e60'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'raw_data', 'mechanism': 'Direct'}}], 'outputDatasets': [], 'runDefinition': {'script': 'data_processing_script.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--datafolder', '$AZUREML_DATAREFERENCE_datafolder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'Compute-Cluster', 'dataReferences': {'datafolder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/f0008e28-da6c-4bfc-b931-56264c048dee/datafolder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {'raw_data': {'dataLocation': {'dataset': {'id': '23f4c02f-90a5-4f21-9470-ed8583e97e60', 'name': None, 'version': '1'}, 'dataPath': None, 'uri': None, 'type': None}, 'mechanism': 'Direct', 'environmentVariableName': 'raw_data', 'pathOnCompute': None, 'overwrite': False, 'options': None}}, 'outputData': {}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'MyEnvironment', 'version': '1', 'assetId': 'azureml://locations/centralus/workspaces/b9dd55e8-c605-4c0b-b3ee-d4324e25cb2e/environments/MyEnvironment/versions/1', 'autoRebuild': True, 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'name': 'project_environment', 'dependencies': ['python=3.8.13', {'pip': ['azureml-sdk']}, 'scikit-learn', 'pandas'], 'channels': ['anaconda', 'conda-forge']}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20230509.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'sshPublicKeys': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'comm ...
#
#
#
#
# StepRunId: 3c4e0fad-7980-451c-964d-fe200e104c3c
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/3c4e0fad-7980-451c-964d-fe200e104c3c?wsid=/subscriptions/8dd92a15-7a35-444a-99e8-7e44a3d0ae52/resourcegroups/azure-ml/workspaces/new_wrokspace&tid=20d3fbd0-4c6d-4dbc-b91c-aa00b337238c
# StepRun( Model Training ) Status: NotStarted
# StepRun( Model Training ) Status: Running
#
# StepRun(Model Training) Execution Summary
# ==========================================
# StepRun( Model Training ) Status: Finished
# {'runId': '3c4e0fad-7980-451c-964d-fe200e104c3c', 'target': 'Compute-Cluster', 'status': 'Completed', 'startTimeUtc': '2023-06-25T22:43:01.481033Z', 'endTimeUtc': '2023-06-25T22:43:19.478466Z', 'services': {}, 'properties': {'ContentSnapshotId': 'dd8502be-929b-49c0-86ce-cc9ab504b413', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '55310afd-5c66-4e5f-84b7-e3c60ad5da06', 'azureml.moduleName': 'Model Training', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'ed53ccaf', 'azureml.pipelinerunid': 'e03c172c-36a7-4762-9d59-5e3cb518083d', 'azureml.pipeline': 'e03c172c-36a7-4762-9d59-5e3cb518083d', 'azureml.rootpipelinerunid': 'e03c172c-36a7-4762-9d59-5e3cb518083d', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'amlctrain', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'model_training_script.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--datafolder', '$AZUREML_DATAREFERENCE_datafolder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'Compute-Cluster', 'dataReferences': {'datafolder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/f0008e28-da6c-4bfc-b931-56264c048dee/datafolder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'MyEnvironment', 'version': '1', 'assetId': 'azureml://locations/centralus/workspaces/b9dd55e8-c605-4c0b-b3ee-d4324e25cb2e/environments/MyEnvironment/versions/1', 'autoRebuild': True, 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'name': 'project_environment', 'dependencies': ['python=3.8.13', {'pip': ['azureml-sdk']}, 'scikit-learn', 'pandas'], 'channels': ['anaconda', 'conda-forge']}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20230509.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'sshPublicKeys': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': False, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}, 'applicationEndpoint ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'e03c172c-36a7-4762-9d59-5e3cb518083d', 'status': 'Completed', 'startTimeUtc': '2023-06-25T22:29:35.341684Z', 'endTimeUtc': '2023-06-25T22:43:20.823938Z', 'services': {}, 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}', 'azureml.continue_on_step_failure': 'False', 'azureml.continue_on_failed_optional_input': 'True', 'azureml.pipelineComponent': 'pipelinerun', 'azureml.pipelines.stages': '{"Initialization":null,"Execution":{"StartTime":"2023-06-25T22:29:35.6159523+00:00","EndTime":"2023-06-25T22:43:20.6994796+00:00","Status":"Finished"}}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://newwroksstoragec8037fbe5.blob.core.windows.net/azureml/ExperimentRun/dcid.e03c172c-36a7-4762-9d59-5e3cb518083d/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=lLV5YimrLFfylOCgvLawyORAjtgaBPYsCdv0snttffk%3D&skoid=119aadee-344a-46e5-ae45-840fc7f3115d&sktid=20d3fbd0-4c6d-4dbc-b91c-aa00b337238c&skt=2023-06-25T16%3A07%3A06Z&ske=2023-06-27T00%3A17%3A06Z&sks=b&skv=2019-07-07&st=2023-06-25T22%3A33%3A25Z&se=2023-06-26T06%3A43%3A25Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://newwroksstoragec8037fbe5.blob.core.windows.net/azureml/ExperimentRun/dcid.e03c172c-36a7-4762-9d59-5e3cb518083d/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=tUVaY%2BLxq89JvBZYcNZOWnkdV9v5UO4IvRCgspvfvLc%3D&skoid=119aadee-344a-46e5-ae45-840fc7f3115d&sktid=20d3fbd0-4c6d-4dbc-b91c-aa00b337238c&skt=2023-06-25T16%3A07%3A06Z&ske=2023-06-27T00%3A17%3A06Z&sks=b&skv=2019-07-07&st=2023-06-25T22%3A33%3A25Z&se=2023-06-26T06%3A43%3A25Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://newwroksstoragec8037fbe5.blob.core.windows.net/azureml/ExperimentRun/dcid.e03c172c-36a7-4762-9d59-5e3cb518083d/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=l4C%2BOxFYTB%2BDRnPzYEXxUOc1DLWQUww3WNet0%2FgbXAg%3D&skoid=119aadee-344a-46e5-ae45-840fc7f3115d&sktid=20d3fbd0-4c6d-4dbc-b91c-aa00b337238c&skt=2023-06-25T16%3A07%3A06Z&ske=2023-06-27T00%3A17%3A06Z&sks=b&skv=2019-07-07&st=2023-06-25T22%3A33%3A25Z&se=2023-06-26T06%3A43%3A25Z&sp=r'}, 'submittedBy': 'francisco jose ocampo giraldo'}
# 'Finished'
