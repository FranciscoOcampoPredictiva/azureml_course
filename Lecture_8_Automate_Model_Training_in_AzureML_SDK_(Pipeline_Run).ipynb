# %% [markdown]
# <a href="https://colab.research.google.com/github/FranciscoOcampoPredictiva/azureml_course/blob/main/Lecture_8_Automate_Model_Training_in_AzureML_SDK_(Pipeline_Run).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1) Installation and Setup

# %%
# Install azureml SDK package
! pip install -q azureml-sdk

# %%
# Import the class
from azureml.core import Workspace

# %%
# Access the workspace from config file and creating a workspace object
ws = Workspace.from_config(path='/content/config.json')

# %% [markdown]
# # 2) Running the Experiment

# %% [markdown]
# ## Creating the custom environment

# %%
from azureml.core import Environment
from azureml.core.environment import CondaDependencies

# %%
myenv = Environment(name="MyEnvironment")
myenv.python.user_managed_dependencies = False
myenv.docker.enabled = True
# Out:
# WARNING:azureml.core.environment:'enabled' is deprecated. Please use the azureml.core.runconfig.DockerConfiguration object with the 'use_docker' param instead.

# %%
# Creating the dependencies object
myenv_dep = CondaDependencies.create(conda_packages=['scikit-learn','pandas'],
                                     pip_packages=['azureml-sdk'])
myenv.python.conda_dependencies = myenv_dep

# %%
# Register the environment to workspace
myenv.register(ws)
# Out:
# {
#     "assetId": "azureml://locations/westus/workspaces/20729af0-6f54-4124-b7dd-3c59794d2397/environments/MyEnvironment/versions/1",
#     "databricks": {
#         "eggLibraries": [],
#         "jarLibraries": [],
#         "mavenLibraries": [],
#         "pypiLibraries": [],
#         "rcranLibraries": []
#     },
#     "docker": {
#         "arguments": [],
#         "baseDockerfile": null,
#         "baseImage": "mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220729.v1",
#         "baseImageRegistry": {
#             "address": null,
#             "password": null,
#             "registryIdentity": null,
#             "username": null
#         },
#         "buildContext": null,
#         "enabled": true,
#         "platform": {
#             "architecture": "amd64",
#             "os": "Linux"
#         },
#         "sharedVolumes": true,
#         "shmSize": null
#     },
#     "environmentVariables": {
#         "EXAMPLE_ENV_VAR": "EXAMPLE_VALUE"
#     },
#     "inferencingStackVersion": null,
#     "name": "MyEnvironment",
#     "python": {
#         "baseCondaEnvironment": null,
#         "condaDependencies": {
#             "channels": [
#                 "anaconda",
#                 "conda-forge"
#             ],
#             "dependencies": [
#                 "python=3.8.13",
#                 {
#                     "pip": [
#                         "azureml-sdk"
#                     ]
#                 },
#                 "scikit-learn",
#                 "pandas"
#             ],
#             "name": "project_environment"
#         },
#         "condaDependenciesFile": null,
#         "interpreterPath": "python",
#         "userManagedDependencies": false
#     },
#     "r": null,
#     "spark": {
#         "packages": [],
#         "precachePackages": true,
#         "repositories": []
#     },
#     "version": "1"
# }

# %% [markdown]
# ## Provision the compute cluster

# %%
# Specify the name of the cluster
cluster_name = 'Compute-Cluster'

# %%
# Import the classes
from azureml.core.compute import AmlCompute, ComputeTarget

# %%
# Configuration for the cluster
compute_config = AmlCompute.provisioning_configuration(vm_size='Standard_DS3_v2',
                                                       max_nodes=2)

# %%
# Create the compute cluster
compute_cluster = ComputeTarget.create(workspace=ws, name=cluster_name, provisioning_configuration=compute_config)
compute_cluster.wait_for_completion(show_output=True)
# Out:
# InProgress.
# SucceededProvisioning operation finished, operation "Succeeded"
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Run configuration steps

# %%
from azureml.core.runconfig import RunConfiguration
run_config = RunConfiguration()

run_config.target = compute_cluster
run_config.environment = myenv

# %% [markdown]
# ## Defining the pipeline steps

# %%
# Importing the classes
from azureml.pipeline.steps import PythonScriptStep
from azureml.pipeline.core import PipelineData

# Access the dataset
input_ds = ws.datasets.get('Churn Modelling Data SDK')

# Pipeline data object
dataFolder = PipelineData(name='datafolder', datastore=ws.get_default_datastore())

# %%
# Step 1- Data Processing
dataPrep_step = PythonScriptStep(name='Data Processing',
                                 source_directory='.',
                                 script_name='data_processing_script.py',
                                 inputs=[input_ds.as_named_input('raw_data')],
                                 outputs=[dataFolder],
                                 runconfig=run_config,
                                 arguments=['--datafolder', dataFolder])

# %%
# Step 2 - Training the Model
train_step = PythonScriptStep(name='Model Training',
                                 source_directory='.',
                                 script_name='model_training_script.py',
                                 inputs=[dataFolder],
                                 runconfig=run_config,
                                 arguments=['--datafolder', dataFolder])

# %% [markdown]
# ## Configure and Build the Pipeline

# %%
steps = [dataPrep_step, train_step] # List of step names

from azureml.pipeline.core import Pipeline
new_pipeline = Pipeline(workspace=ws, steps=steps)

# %% [markdown]
# ## Creating experiment and running the pipeline

# %%
# Creating the experiment
from azureml.core import Experiment
new_experiment = Experiment(workspace=ws, name='PipelineExperiment')

# Submit the experiment run
new_pipeline_run = new_experiment.submit(new_pipeline)
new_pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step Data Processing [def2c3e5][c2a2d3aa-eb4c-4de5-93af-ac26619c1dab], (This step will run and generate new outputs)
# Created step Model Training [9f4de622][9c28d934-e8f3-4e19-a173-bf0ea8a87078], (This step will run and generate new outputs)
# Submitted PipelineRun 1d4ca0c9-efb2-4842-b0b7-faa82a3d52f8
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/1d4ca0c9-efb2-4842-b0b7-faa82a3d52f8?wsid=/subscriptions/76d4f7e1-3c6a-41a3-968f-043a0cb83503/resourcegroups/azureml-sdk-rg/workspaces/azureml-sdk-ws&tid=aca956d5-1716-486c-9340-ffedc6d009ae
# PipelineRunId: 1d4ca0c9-efb2-4842-b0b7-faa82a3d52f8
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/1d4ca0c9-efb2-4842-b0b7-faa82a3d52f8?wsid=/subscriptions/76d4f7e1-3c6a-41a3-968f-043a0cb83503/resourcegroups/azureml-sdk-rg/workspaces/azureml-sdk-ws&tid=aca956d5-1716-486c-9340-ffedc6d009ae
# PipelineRun Status: Running
#
#
# StepRunId: ffa1ee7e-5d49-4f60-b29f-c612d6304b66
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/ffa1ee7e-5d49-4f60-b29f-c612d6304b66?wsid=/subscriptions/76d4f7e1-3c6a-41a3-968f-043a0cb83503/resourcegroups/azureml-sdk-rg/workspaces/azureml-sdk-ws&tid=aca956d5-1716-486c-9340-ffedc6d009ae
# StepRun( Data Processing ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2022/09/11 15:30:08 Downloading source code...
# 2022/09/11 15:30:08 Finished downloading source code
# 2022/09/11 15:30:09 Creating Docker network: acb_default_network, driver: 'bridge'
# 2022/09/11 15:30:09 Successfully set up Docker network: acb_default_network
# 2022/09/11 15:30:09 Setting up Docker configuration...
# 2022/09/11 15:30:09 Successfully set up Docker configuration
# 2022/09/11 15:30:09 Logging in to registry: 20729af06f544124b7dd3c59794d2397.azurecr.io
# 2022/09/11 15:30:10 Successfully logged into 20729af06f544124b7dd3c59794d2397.azurecr.io
# 2022/09/11 15:30:10 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/09/11 15:30:10 Scanning for dependencies...
# 2022/09/11 15:30:11 Successfully scanned dependencies
# 2022/09/11 15:30:11 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/21 : FROM mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220729.v1@sha256:86041abadd8cff9c2ed506b3477d45df5efa54f2adff0359d73cb825ab78510a
# mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220729.v1@sha256:86041abadd8cff9c2ed506b3477d45df5efa54f2adff0359d73cb825ab78510a: Pulling from azureml/openmpi4.1.0-ubuntu20.04
# d7bfe07ed847: Pulling fs layer
# 1e1c6f32e53a: Pulling fs layer
# 5bd7167b78fb: Pulling fs layer
# 7692bb371255: Pulling fs layer
# 4ab61f330ff9: Pulling fs layer
# 4f52b9f71c0c: Pulling fs layer
# 4a25856e15bf: Pulling fs layer
# e851225f62a6: Pulling fs layer
# 2eed56b7bde9: Pulling fs layer
# 8dcad2ef365c: Pulling fs layer
# 4f52b9f71c0c: Waiting
# 4a25856e15bf: Waiting
# e851225f62a6: Waiting
# 2eed56b7bde9: Waiting
# 8dcad2ef365c: Waiting
# 7692bb371255: Waiting
# 4ab61f330ff9: Waiting
# d7bfe07ed847: Verifying Checksum
# d7bfe07ed847: Download complete
# 5bd7167b78fb: Verifying Checksum
# 5bd7167b78fb: Download complete
# 4ab61f330ff9: Verifying Checksum
# 4ab61f330ff9: Download complete
# 7692bb371255: Verifying Checksum
# 7692bb371255: Download complete
# 4a25856e15bf: Verifying Checksum
# 4a25856e15bf: Download complete
# e851225f62a6: Verifying Checksum
# e851225f62a6: Download complete
# 4f52b9f71c0c: Verifying Checksum
# 4f52b9f71c0c: Download complete
# 8dcad2ef365c: Verifying Checksum
# 8dcad2ef365c: Download complete
# 2eed56b7bde9: Verifying Checksum
# 2eed56b7bde9: Download complete
# 1e1c6f32e53a: Verifying Checksum
# 1e1c6f32e53a: Download complete
# d7bfe07ed847: Pull complete
# 1e1c6f32e53a: Pull complete
# 5bd7167b78fb: Pull complete
# 7692bb371255: Pull complete
# 4ab61f330ff9: Pull complete
# 4f52b9f71c0c: Pull complete
# 4a25856e15bf: Pull complete
# e851225f62a6: Pull complete
# 2eed56b7bde9: Pull complete
# 8dcad2ef365c: Pull complete
# Digest: sha256:86041abadd8cff9c2ed506b3477d45df5efa54f2adff0359d73cb825ab78510a
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220729.v1@sha256:86041abadd8cff9c2ed506b3477d45df5efa54f2adff0359d73cb825ab78510a
#  ---> 66ef907b4cf1
# Step 2/21 : USER root
#  ---> Running in 24fe5ad1c12f
# Removing intermediate container 24fe5ad1c12f
#  ---> 8534588e6d31
# Step 3/21 : RUN mkdir -p $HOME/.cache
#  ---> Running in 0096af88eedc
# Removing intermediate container 0096af88eedc
#  ---> 1d51bb908499
# Step 4/21 : WORKDIR /
#  ---> Running in 5261d93b7640
# Removing intermediate container 5261d93b7640
#  ---> 7297693f4827
# Step 5/21 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> b45a66258ffb
# Step 6/21 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in f311d866317e
# Removing intermediate container f311d866317e
#  ---> aa0375f3026b
# Step 7/21 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 8ce99bcd5b29
# Step 8/21 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 00907b2cd4f9
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# mkl-service-2.4.0    | 62 KB     |            |   0%
# mkl-service-2.4.0    | 62 KB     | ########## | 100%
#
# mkl_random-1.2.2     | 341 KB    |            |   0%
# mkl_random-1.2.2     | 341 KB    | ########## | 100%
#
# numpy-base-1.23.1    | 7.1 MB    |            |   0%
# numpy-base-1.23.1    | 7.1 MB    | ########8  |  89%
# numpy-base-1.23.1    | 7.1 MB    | ########## | 100%
#
# packaging-21.3       | 35 KB     |            |   0%
# packaging-21.3       | 35 KB     | ########## | 100%
#
# mkl_fft-1.3.1        | 200 KB    |            |   0%
# mkl_fft-1.3.1        | 200 KB    | ########## | 100%
#
# threadpoolctl-2.2.0  | 16 KB     |            |   0%
# threadpoolctl-2.2.0  | 16 KB     | ########## | 100%
#
# numexpr-2.8.3        | 133 KB    |            |   0%
# numexpr-2.8.3        | 133 KB    | ########## | 100%
#
# sqlite-3.39.2        | 1.5 MB    |            |   0%
# sqlite-3.39.2        | 1.5 MB    | ########## | 100%
# sqlite-3.39.2        | 1.5 MB    | ########## | 100%
#
# libffi-3.3           | 54 KB     |            |   0%
# libffi-3.3           | 54 KB     | ########## | 100%
#
# libstdcxx-ng-11.2.0  | 6.1 MB    |            |   0%
# libstdcxx-ng-11.2.0  | 6.1 MB    | #######8   |  79%
# libstdcxx-ng-11.2.0  | 6.1 MB    | ########## | 100%
#
# libgcc-ng-11.2.0     | 8.5 MB    |            |   0%
# libgcc-ng-11.2.0     | 8.5 MB    | ###7       |  37%
# libgcc-ng-11.2.0     | 8.5 MB    | #########4 |  94%
# libgcc-ng-11.2.0     | 8.5 MB    | ########## | 100%
#
# six-1.16.0           | 19 KB     |            |   0%
# six-1.16.0           | 19 KB     | ########## | 100%
#
# libgfortran4-7.5.0   | 1.3 MB    |            |   0%
# libgfortran4-7.5.0   | 1.3 MB    | ########## | 100%
# libgfortran4-7.5.0   | 1.3 MB    | ########## | 100%
#
# zlib-1.2.12          | 130 KB    |            |   0%
# zlib-1.2.12          | 130 KB    | ########## | 100%
#
# bottleneck-1.3.5     | 125 KB    |            |   0%
# bottleneck-1.3.5     | 125 KB    | ########## | 100%
#
# wheel-0.37.1         | 31 KB     |            |   0%
# wheel-0.37.1         | 31 KB     | ########## | 100%
#
# mkl-2021.4.0         | 219.1 MB  |            |   0%
# mkl-2021.4.0         | 219.1 MB  | 3          |   3%
# mkl-2021.4.0         | 219.1 MB  | 7          |   7%
# mkl-2021.4.0         | 219.1 MB  | #          |  11%
# mkl-2021.4.0         | 219.1 MB  | #3         |  14%
# mkl-2021.4.0         | 219.1 MB  | #7         |  18%
# mkl-2021.4.0         | 219.1 MB  | ##         |  21%
# mkl-2021.4.0         | 219.1 MB  | ##4        |  24%
# mkl-2021.4.0         | 219.1 MB  | ##7        |  27%
# mkl-2021.4.0         | 219.1 MB  | ###        |  30%
# mkl-2021.4.0         | 219.1 MB  | ###3       |  33%
# mkl-2021.4.0         | 219.1 MB  | ###5       |  36%
# mkl-2021.4.0         | 219.1 MB  | ###8       |  39%
# mkl-2021.4.0         | 219.1 MB  | ####1      |  42%
# mkl-2021.4.0         | 219.1 MB  | ####4      |  45%
# mkl-2021.4.0         | 219.1 MB  | ####8      |  48%
# mkl-2021.4.0         | 219.1 MB  | #####1     |  52%
# mkl-2021.4.0         | 219.1 MB  | #####4     |  55%
# mkl-2021.4.0         | 219.1 MB  | #####8     |  58%
# mkl-2021.4.0         | 219.1 MB  | ######1    |  62%
# mkl-2021.4.0         | 219.1 MB  | ######4    |  65%
# mkl-2021.4.0         | 219.1 MB  | ######7    |  68%
# mkl-2021.4.0         | 219.1 MB  | #######    |  71%
# mkl-2021.4.0         | 219.1 MB  | #######4   |  75%
# mkl-2021.4.0         | 219.1 MB  | #######7   |  78%
# mkl-2021.4.0         | 219.1 MB  | ########1  |  81%
# mkl-2021.4.0         | 219.1 MB  | ########4  |  84%
# mkl-2021.4.0         | 219.1 MB  | ########8  |  89%
# mkl-2021.4.0         | 219.1 MB  | #########2 |  92%
# mkl-2021.4.0         | 219.1 MB  | #########6 |  96%
#
# mkl-2021.4.0         | 219.1 MB  | ########## | 100%
# mkl-2021.4.0         | 219.1 MB  | ########## | 100%
#
# intel-openmp-2021.4. | 8.8 MB    |            |   0%
# intel-openmp-2021.4. | 8.8 MB    | #######6   |  77%
# intel-openmp-2021.4. | 8.8 MB    | ########## | 100%
#
# numpy-1.23.1         | 10 KB     |            |   0%
# numpy-1.23.1         | 10 KB     | ########## | 100%
#
# openssl-1.1.1q       | 3.8 MB    |            |   0%
# openssl-1.1.1q       | 3.8 MB    | ###4       |  35%
# openssl-1.1.1q       | 3.8 MB    | ########## | 100%
# openssl-1.1.1q       | 3.8 MB    | ########## | 100%
#
# ca-certificates-2022 | 131 KB    |            |   0%
# ca-certificates-2022 | 131 KB    | ########## | 100%
#
# pyparsing-3.0.4      | 78 KB     |            |   0%
# pyparsing-3.0.4      | 78 KB     | ########## | 100%
#
# _openmp_mutex-5.1    | 20 KB     |            |   0%
# _openmp_mutex-5.1    | 20 KB     | ########## | 100%
#
# scipy-1.7.3          | 21.4 MB   |            |   0%
# scipy-1.7.3          | 21.4 MB   | ##7        |  27%
# scipy-1.7.3          | 21.4 MB   | #####4     |  55%
# scipy-1.7.3          | 21.4 MB   | #########8 |  98%
# scipy-1.7.3          | 21.4 MB   | ########## | 100%
#
# certifi-2022.6.15    | 156 KB    |            |   0%
# certifi-2022.6.15    | 156 KB    | ########## | 100%
#
# joblib-1.1.0         | 211 KB    |            |   0%
# joblib-1.1.0         | 211 KB    | 7          |   8%
# joblib-1.1.0         | 211 KB    | ########## | 100%
#
# pip-22.1.2           | 2.9 MB    |            |   0%
# pip-22.1.2           | 2.9 MB    | #########3 |  94%
# pip-22.1.2           | 2.9 MB    | ########## | 100%
#
# pandas-1.4.3         | 12.6 MB   |            |   0%
# pandas-1.4.3         | 12.6 MB   | #####9     |  60%
# pandas-1.4.3         | 12.6 MB   | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# tk-8.6.12            | 3.3 MB    |            |   0%
# tk-8.6.12            | 3.3 MB    | ########## | 100%
# tk-8.6.12            | 3.3 MB    | ########## | 100%
#
# libgfortran-ng-7.5.0 | 22 KB     |            |   0%
# libgfortran-ng-7.5.0 | 22 KB     | ########## | 100%
#
# scikit-learn-1.1.1   | 8.4 MB    |            |   0%
# scikit-learn-1.1.1   | 8.4 MB    |            |   0%
# scikit-learn-1.1.1   | 8.4 MB    | 3          |   4%
# scikit-learn-1.1.1   | 8.4 MB    | ###9       |  39%
# scikit-learn-1.1.1   | 8.4 MB    | ######2    |  63%
# scikit-learn-1.1.1   | 8.4 MB    | ########## | 100%
# scikit-learn-1.1.1   | 8.4 MB    | ########## | 100%
#
# setuptools-61.2.0    | 1.3 MB    |            |   0%
# setuptools-61.2.0    | 1.3 MB    | ########## | 100%
# setuptools-61.2.0    | 1.3 MB    | ########## | 100%
#
# python-dateutil-2.8. | 241 KB    |            |   0%
# python-dateutil-2.8. | 241 KB    | ########## | 100%
#
# pytz-2022.1          | 243 KB    |            |   0%
# pytz-2022.1          | 243 KB    | ########## | 100%
# pytz-2022.1          | 243 KB    | ########## | 100%
#
# libgomp-11.2.0       | 560 KB    |            |   0%
# libgomp-11.2.0       | 560 KB    | ########## | 100%
# libgomp-11.2.0       | 560 KB    | ########## | 100%
#
# readline-8.1.2       | 423 KB    |            |   0%
# readline-8.1.2       | 423 KB    | ########## | 100%
# readline-8.1.2       | 423 KB    | ########## | 100%
#
# ld_impl_linux-64-2.3 | 732 KB    |            |   0%
# ld_impl_linux-64-2.3 | 732 KB    | ########## | 100%
# ld_impl_linux-64-2.3 | 732 KB    | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# ncurses-6.3          | 1.1 MB    |            |   0%
# ncurses-6.3          | 1.1 MB    | ########## | 100%
# ncurses-6.3          | 1.1 MB    | ########## | 100%
#
# xz-5.2.5             | 389 KB    |            |   0%
# xz-5.2.5             | 389 KB    | #########  |  91%
# xz-5.2.5             | 389 KB    | ########## | 100%
#
# python-3.8.13        | 22.7 MB   |            |   0%
# python-3.8.13        | 22.7 MB   | #7         |  17%
# python-3.8.13        | 22.7 MB   | #####4     |  55%
# python-3.8.13        | 22.7 MB   | ########3  |  84%
# python-3.8.13        | 22.7 MB   | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.ghwwj2xk.requirements.txt']
# Pip subprocess output:
# Collecting azureml-sdk
#   Downloading azureml_sdk-1.45.0-py3-none-any.whl (2.7 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.45.0
#   Downloading azureml_dataset_runtime-1.45.0-py3-none-any.whl (2.3 kB)
# Collecting azureml-pipeline~=1.45.0
#   Downloading azureml_pipeline-1.45.0-py3-none-any.whl (2.4 kB)
# Collecting azureml-train-core~=1.45.0
#   Downloading azureml_train_core-1.45.0-py3-none-any.whl (8.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 105.8 MB/s eta 0:00:00
# Collecting azureml-train-automl-client~=1.45.0
#   Downloading azureml_train_automl_client-1.45.0-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.0/136.0 kB 34.0 MB/s eta 0:00:00
# Collecting azureml-core~=1.45.0
#   Downloading azureml_core-1.45.0.post1-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 119.3 MB/s eta 0:00:00
# Collecting urllib3<2.0.0,>=1.23
#   Downloading urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.4/140.4 kB 30.1 MB/s eta 0:00:00
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.4/141.4 kB 30.5 MB/s eta 0:00:00
# Collecting requests[socks]<3.0.0,>=2.19.1
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 13.4 MB/s eta 0:00:00
# Collecting argcomplete<3
#   Downloading argcomplete-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.3-py3-none-any.whl (15 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.4.0-py3-none-any.whl (18 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Collecting paramiko<3.0.0,>=2.0.8
#   Downloading paramiko-2.11.0-py2.py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.9/212.9 kB 39.3 MB/s eta 0:00:00
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.2.0-py2.py3-none-any.whl (39 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<38.0.0
#   Downloading cryptography-37.0.4-cp36-abi3-manylinux_2_24_x86_64.whl (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 90.8 MB/s eta 0:00:00
# Collecting pyopenssl<23.0.0
#   Downloading pyOpenSSL-22.0.0-py2.py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 12.3 MB/s eta 0:00:00
# Collecting msal-extensions<=1.0.0,>=0.3.0
#   Downloading msal_extensions-1.0.0-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: packaging<22.0,>=20.0 in /azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99/lib/python3.8/site-packages (from azureml-core~=1.45.0->azureml-sdk->-r /azureml-environment-setup/condaenv.ghwwj2xk.requirements.txt (line 1)) (21.3)
# Collecting docker<6.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.2/146.2 kB 31.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in /azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99/lib/python3.8/site-packages (from azureml-core~=1.45.0->azureml-sdk->-r /azureml-environment-setup/condaenv.ghwwj2xk.requirements.txt (line 1)) (2.8.2)
# Collecting humanfriendly<11.0,>=4.7
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 20.4 MB/s eta 0:00:00
# Collecting contextlib2<22.0.0
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting ndg-httpsclient<=0.5.1
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting adal<=1.2.7,>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 11.5 MB/s eta 0:00:00
# Collecting pkginfo
#   Downloading pkginfo-1.8.3-py2.py3-none-any.whl (26 kB)
# Collecting azure-mgmt-storage<=20.0.0,>=16.0.0
#   Downloading azure_mgmt_storage-20.0.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 104.5 MB/s eta 0:00:00
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.10.1-py3-none-any.whl (27 kB)
# Collecting knack~=0.9.0
#   Downloading knack-0.9.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 12.9 MB/s eta 0:00:00
# Collecting jmespath<2.0.0
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: pytz in /azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99/lib/python3.8/site-packages (from azureml-core~=1.45.0->azureml-sdk->-r /azureml-environment-setup/condaenv.ghwwj2xk.requirements.txt (line 1)) (2022.1)
# Collecting msrestazure<=0.6.4,>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 7.6 MB/s eta 0:00:00
# Collecting msrest<=0.7.1,>=0.5.1
#   Downloading msrest-0.7.1-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 16.3 MB/s eta 0:00:00
# Collecting azure-mgmt-containerregistry<11,>=8.2.0
#   Downloading azure_mgmt_containerregistry-10.0.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 76.7 MB/s eta 0:00:00
# Collecting azure-mgmt-authorization<3,>=0.40.0
#   Downloading azure_mgmt_authorization-2.0.0-py2.py3-none-any.whl (465 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.2/465.2 kB 72.6 MB/s eta 0:00:00
# Collecting azure-mgmt-keyvault<11.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-10.1.0-py3-none-any.whl (605 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.9/605.9 kB 62.3 MB/s eta 0:00:00
# Collecting msal<2.0.0,>=1.15.0
#   Downloading msal-1.18.0-py2.py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.4/82.4 kB 11.8 MB/s eta 0:00:00
# Collecting azure-mgmt-resource<22.0.0,>=15.0.0
#   Downloading azure_mgmt_resource-21.1.0-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 63.2 MB/s eta 0:00:00
# Collecting azure-core<2.0.0
#   Downloading azure_core-1.25.1-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.8/178.8 kB 32.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy!=1.19.3 in /azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99/lib/python3.8/site-packages (from azureml-dataset-runtime[fuse]~=1.45.0->azureml-sdk->-r /azureml-environment-setup/condaenv.ghwwj2xk.requirements.txt (line 1)) (1.23.1)
# Collecting azureml-dataprep<4.3.0a,>=4.2.0a
#   Downloading azureml_dataprep-4.2.2-py3-none-any.whl (43.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.4/43.4 MB 50.6 MB/s eta 0:00:00
# Collecting pyarrow<6.0.1,>=0.17.0
#   Downloading pyarrow-6.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.6/25.6 MB 84.4 MB/s eta 0:00:00
# Collecting fusepy<4.0.0,>=3.0.1
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting azureml-pipeline-core~=1.45.0
#   Downloading azureml_pipeline_core-1.45.0-py3-none-any.whl (312 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.7/312.7 kB 56.0 MB/s eta 0:00:00
# Collecting azureml-pipeline-steps~=1.45.0
#   Downloading azureml_pipeline_steps-1.45.0-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.3/69.3 kB 16.8 MB/s eta 0:00:00
# Collecting azureml-automl-core~=1.45.0
#   Downloading azureml_automl_core-1.45.0-py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.1/240.1 kB 33.2 MB/s eta 0:00:00
# Collecting azureml-telemetry~=1.45.0
#   Downloading azureml_telemetry-1.45.0-py3-none-any.whl (30 kB)
# Collecting azureml-train-restclients-hyperdrive~=1.45.0
#   Downloading azureml_train_restclients_hyperdrive-1.45.0-py3-none-any.whl (18 kB)
# Collecting typing-extensions>=4.0.1
#   Downloading typing_extensions-4.3.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: six>=1.11.0 in /azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99/lib/python3.8/site-packages (from azure-core<2.0.0->azureml-core~=1.45.0->azureml-sdk->-r /azureml-environment-setup/condaenv.ghwwj2xk.requirements.txt (line 1)) (1.16.0)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.3.2-py3-none-any.whl (26 kB)
# Collecting azureml-dataprep-rslex~=2.8.0dev0
#   Downloading azureml_dataprep_rslex-2.8.1-cp38-cp38-manylinux2010_x86_64.whl (16.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 99.1 MB/s eta 0:00:00
# Collecting azureml-dataprep-native<39.0.0,>=38.0.0
#   Downloading azureml_dataprep_native-38.0.0-cp38-cp38-manylinux1_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 92.1 MB/s eta 0:00:00
# Collecting jsonschema
#   Downloading jsonschema-4.16.0-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 15.7 MB/s eta 0:00:00
# Collecting azure-identity==1.7.0
#   Downloading azure_identity-1.7.0-py2.py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 23.8 MB/s eta 0:00:00
# Collecting dotnetcore2<4.0.0,>=3.0.0
#   Downloading dotnetcore2-3.1.23-py3-none-manylinux1_x86_64.whl (31.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.1/31.1 MB 65.1 MB/s eta 0:00:00
# Collecting cloudpickle<3.0.0,>=1.1.0
#   Downloading cloudpickle-2.2.0-py3-none-any.whl (25 kB)
# Collecting pyyaml<7.0.0,>=5.1.0
#   Downloading PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
#      ━━━━━━━━━━━━���━━━━━━━━━━━━━━━━━━━━━━━━━ 701.2/701.2 kB 61.5 MB/s eta 0:00:00
# Collecting msal-extensions<=1.0.0,>=0.3.0
#   Downloading msal_extensions-0.3.1-py2.py3-none-any.whl (18 kB)
# Collecting applicationinsights
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 9.1 MB/s eta 0:00:00
# Collecting cffi>=1.12
#   Downloading cffi-1.15.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.7/442.7 kB 74.8 MB/s eta 0:00:00
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.4.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.0/55.0 kB 13.2 MB/s eta 0:00:00
# Collecting tabulate
#   Downloading tabulate-0.8.10-py3-none-any.whl (29 kB)
# Collecting pygments
#   Downloading Pygments-2.13.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 104.1 MB/s eta 0:00:00
# Collecting portalocker<3,>=1.0
#   Downloading portalocker-2.5.1-py2.py3-none-any.whl (15 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99/lib/python3.8/site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core~=1.45.0->azureml-sdk->-r /azureml-environment-setup/condaenv.ghwwj2xk.requirements.txt (line 1)) (2022.6.15)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 16.7 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99/lib/python3.8/site-packages (from packaging<22.0,>=20.0->azureml-core~=1.45.0->azureml-sdk->-r /azureml-environment-setup/condaenv.ghwwj2xk.requirements.txt (line 1)) (3.0.4)
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 70.7 MB/s eta 0:00:00
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-4.0.0-cp36-abi3-manylinux_2_28_x86_64.whl (594 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.4/594.4 kB 63.1 MB/s eta 0:00:00
# Collecting charset-normalizer<3,>=2
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 15.1 MB/s eta 0:00:00
# Collecting PySocks!=1.5.7,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.8.0-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 11.0 MB/s eta 0:00:00
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 27.5 MB/s eta 0:00:00
# Collecting distro>=1.2.0
#   Downloading distro-1.7.0-py3-none-any.whl (20 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.1-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 5.9 MB/s eta 0:00:00
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Downloading pyrsistent-0.18.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (119 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 kB 12.7 MB/s eta 0:00:00
# Collecting pkgutil-resolve-name>=1.3.10
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Collecting attrs>=17.4.0
#   Downloading attrs-22.1.0-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 12.7 MB/s eta 0:00:00
# Collecting importlib-resources>=1.4.0
#   Downloading importlib_resources-5.9.0-py3-none-any.whl (33 kB)
# Collecting zipp>=3.1.0
#   Downloading zipp-3.8.1-py3-none-any.whl (5.6 kB)
# Building wheels for collected packages: fusepy
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10503 sha256=4e20ee9c921effb704e00999584c9b45c91a17ba9c87c1bed5a9a7fb1c4e8611
#   Stored in directory: /root/.cache/pip/wheels/7f/41/10/f70b83a1164fdb95e7bc37bace13114a024227e56c2fee02bb
# Successfully built fusepy
# Installing collected packages: pyasn1, fusepy, backports.weakref, azureml-dataprep-rslex, azureml-dataprep-native, azure-common, applicationinsights, zipp, websocket-client, urllib3, typing-extensions, tabulate, pyyaml, PySocks, pyrsistent, PyJWT, pygments, pycparser, pyarrow, portalocker, pkgutil-resolve-name, pkginfo, pathspec, oauthlib, jsonpickle, jmespath, jeepney, isodate, idna, humanfriendly, distro, contextlib2, cloudpickle, charset-normalizer, bcrypt, backports.tempfile, attrs, argcomplete, requests, knack, importlib-resources, dotnetcore2, cffi, requests-oauthlib, pynacl, jsonschema, docker, cryptography, azure-core, SecretStorage, pyopenssl, paramiko, msrest, azure-mgmt-core, adal, ndg-httpsclient, msrestazure, msal, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, msal-extensions, azureml-train-restclients-hyperdrive, azure-graphrbac, azureml-core, azure-identity, azureml-telemetry, azureml-pipeline-core, azureml-dataprep, azureml-train-core, azureml-dataset-runtime, azureml-automl-core, azureml-train-automl-client, azureml-pipeline-steps, azureml-pipeline, azureml-sdk
# Successfully installed PyJWT-2.4.0 PySocks-1.7.1 SecretStorage-3.3.3 adal-1.2.7 applicationinsights-0.11.10 argcomplete-2.0.0 attrs-22.1.0 azure-common-1.1.28 azure-core-1.25.1 azure-graphrbac-0.61.1 azure-identity-1.7.0 azure-mgmt-authorization-2.0.0 azure-mgmt-containerregistry-10.0.0 azure-mgmt-core-1.3.2 azure-mgmt-keyvault-10.1.0 azure-mgmt-resource-21.1.0 azure-mgmt-storage-20.0.0 azureml-automl-core-1.45.0 azureml-core-1.45.0.post1 azureml-dataprep-4.2.2 azureml-dataprep-native-38.0.0 azureml-dataprep-rslex-2.8.1 azureml-dataset-runtime-1.45.0 azureml-pipeline-1.45.0 azureml-pipeline-core-1.45.0 azureml-pipeline-steps-1.45.0 azureml-sdk-1.45.0 azureml-telemetry-1.45.0 azureml-train-automl-client-1.45.0 azureml-train-core-1.45.0 azureml-train-restclients-hyperdrive-1.45.0 backports.tempfile-1.0 backports.weakref-1.0.post1 bcrypt-4.0.0 cffi-1.15.1 charset-normalizer-2.1.1 cloudpickle-2.2.0 contextlib2-21.6.0 cryptography-37.0.4 distro-1.7.0 docker-5.0.3 dotnetcore2-3.1.23 fusepy-3.0.1 humanfriendly-10.0 idna-3.3 importlib-resources-5.9.0 isodate-0.6.1 jeepney-0.8.0 jmespath-1.0.1 jsonpickle-2.2.0 jsonschema-4.16.0 knack-0.9.0 msal-1.18.0 msal-extensions-0.3.1 msrest-0.7.1 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.2.1 paramiko-2.11.0 pathspec-0.10.1 pkginfo-1.8.3 pkgutil-resolve-name-1.3.10 portalocker-2.5.1 pyarrow-6.0.0 pyasn1-0.4.8 pycparser-2.21 pygments-2.13.0 pynacl-1.5.0 pyopenssl-22.0.0 pyrsistent-0.18.1 pyyaml-6.0 requests-2.28.1 requests-oauthlib-1.3.1 tabulate-0.8.10 typing-extensions-4.3.0 urllib3-1.26.12 websocket-client-1.4.1 zipp-3.8.1
#
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 4.14.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 00907b2cd4f9
#  ---> 30c1b796ae5f
# Step 9/21 : ENV PATH /azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99/bin:$PATH
#  ---> Running in 51c1bc6ecc14
# Removing intermediate container 51c1bc6ecc14
#  ---> 15e83ad79d3c
# Step 10/21 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> 5bcd3cf81fff
# Step 11/21 : RUN echo "Copying environment context"
#  ---> Running in 8754f13b4bcf
# Copying environment context
# Removing intermediate container 8754f13b4bcf
#  ---> 46d5fe932405
# Step 12/21 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 53ff0ad044b8
# Step 13/21 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99
#  ---> Running in c5a6ff87b823
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container c5a6ff87b823
#  ---> ac09550f2195
# Step 14/21 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99
#  ---> Running in d7e08a1bc70a
# Removing intermediate container d7e08a1bc70a
#  ---> c580f3a366e5
# Step 15/21 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99/lib:$LD_LIBRARY_PATH
#  ---> Running in bedb7a7ae558
# Removing intermediate container bedb7a7ae558
#  ---> 7e47ea95912a
# Step 16/21 : ENV CONDA_DEFAULT_ENV=azureml_9213d7cc2cbd0e159e0a1ad4c5452b99 CONDA_PREFIX=/azureml-envs/azureml_9213d7cc2cbd0e159e0a1ad4c5452b99
#  ---> Running in 125898ca5538
# Removing intermediate container 125898ca5538
#  ---> c09ab0176b70
# Step 17/21 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> b6041f333275
# Step 18/21 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 6bf9b6261adc
# Removing intermediate container 6bf9b6261adc
#  ---> 48f7730e560a
# Step 19/21 : RUN rm -rf azureml-environment-setup
#  ---> Running in b4f7b8999f33
# Removing intermediate container b4f7b8999f33
#  ---> a15076a51869
# Step 20/21 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 98cd9397dcad
# Removing intermediate container 98cd9397dcad
#  ---> 69dca9a26db1
# Step 21/21 : CMD ["bash"]
#  ---> Running in 1a9d9f4f2656
# Removing intermediate container 1a9d9f4f2656
#  ---> 46e46877e7d6
# Successfully built 46e46877e7d6
# Successfully tagged 20729af06f544124b7dd3c59794d2397.azurecr.io/azureml/azureml_5ef0227ccb95815183b084b36f0e8dc1:latest
# Successfully tagged 20729af06f544124b7dd3c59794d2397.azurecr.io/azureml/azureml_5ef0227ccb95815183b084b36f0e8dc1:1
# 2022/09/11 15:33:48 Successfully executed container: acb_step_0
# 2022/09/11 15:33:48 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/09/11 15:33:48 Pushing image: 20729af06f544124b7dd3c59794d2397.azurecr.io/azureml/azureml_5ef0227ccb95815183b084b36f0e8dc1:1, attempt 1
# The push refers to repository [20729af06f544124b7dd3c59794d2397.azurecr.io/azureml/azureml_5ef0227ccb95815183b084b36f0e8dc1]
# 740a88dae04d: Preparing
# 94b8173c4f0e: Preparing
# c87f528e95da: Preparing
# 9e8fb042c730: Preparing
# 6b655fdddf71: Preparing
# 687d8356d365: Preparing
# e1204abc6bc2: Preparing
# d45fc2e9c061: Preparing
# fa82d50f60b5: Preparing
# 26ddfcb7090e: Preparing
# ae39a55da88b: Preparing
# 8fac15dd911c: Preparing
# a001dd064a81: Preparing
# 7e907f0764b8: Preparing
# 29138effb439: Preparing
# 94f8ff43aced: Preparing
# 982dbd99d0fd: Preparing
# dbfe8c01e73c: Preparing
# 59808e8443ed: Preparing
# af7ed92504ae: Preparing
# 687d8356d365: Waiting
# e1204abc6bc2: Waiting
# d45fc2e9c061: Waiting
# fa82d50f60b5: Waiting
# 26ddfcb7090e: Waiting
# ae39a55da88b: Waiting
# 982dbd99d0fd: Waiting
# 8fac15dd911c: Waiting
# dbfe8c01e73c: Waiting
# a001dd064a81: Waiting
# 59808e8443ed: Waiting
# 7e907f0764b8: Waiting
# 29138effb439: Waiting
# 94f8ff43aced: Waiting
# af7ed92504ae: Waiting
# 740a88dae04d: Pushed
# 6b655fdddf71: Pushed
# 94b8173c4f0e: Pushed
# 9e8fb042c730: Pushed
# c87f528e95da: Pushed
# e1204abc6bc2: Pushed
# d45fc2e9c061: Pushed
# fa82d50f60b5: Pushed
# 26ddfcb7090e: Pushed
# ae39a55da88b: Pushed
# 8fac15dd911c: Pushed
# 94f8ff43aced: Pushed
# a001dd064a81: Pushed
# 7e907f0764b8: Pushed
# 982dbd99d0fd: Pushed
# dbfe8c01e73c: Pushed
# af7ed92504ae: Pushed
# 29138effb439: Pushed
# 59808e8443ed: Pushed
# 687d8356d365: Pushed
# 1: digest: sha256:09b2f3d499dc20e5bd06f86cf25a4ae96756c2d82a3ee039b8337d1361b4359c size: 4513
# 2022/09/11 15:35:28 Successfully pushed image: 20729af06f544124b7dd3c59794d2397.azurecr.io/azureml/azureml_5ef0227ccb95815183b084b36f0e8dc1:1
# 2022/09/11 15:35:28 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/09/11 15:35:28 Pushing image: 20729af06f544124b7dd3c59794d2397.azurecr.io/azureml/azureml_5ef0227ccb95815183b084b36f0e8dc1:latest, attempt 1
# The push refers to repository [20729af06f544124b7dd3c59794d2397.azurecr.io/azureml/azureml_5ef0227ccb95815183b084b36f0e8dc1]
# 740a88dae04d: Preparing
# 94b8173c4f0e: Preparing
# c87f528e95da: Preparing
# 9e8fb042c730: Preparing
# 6b655fdddf71: Preparing
# 687d8356d365: Preparing
# e1204abc6bc2: Preparing
# d45fc2e9c061: Preparing
# fa82d50f60b5: Preparing
# 26ddfcb7090e: Preparing
# ae39a55da88b: Preparing
# 8fac15dd911c: Preparing
# a001dd064a81: Preparing
# 7e907f0764b8: Preparing
# 29138effb439: Preparing
# 94f8ff43aced: Preparing
# 982dbd99d0fd: Preparing
# dbfe8c01e73c: Preparing
# 59808e8443ed: Preparing
# af7ed92504ae: Preparing
# 687d8356d365: Waiting
# e1204abc6bc2: Waiting
# d45fc2e9c061: Waiting
# fa82d50f60b5: Waiting
# 26ddfcb7090e: Waiting
# ae39a55da88b: Waiting
# 8fac15dd911c: Waiting
# a001dd064a81: Waiting
# 7e907f0764b8: Waiting
# 29138effb439: Waiting
# 94f8ff43aced: Waiting
# 982dbd99d0fd: Waiting
# dbfe8c01e73c: Waiting
# 59808e8443ed: Waiting
# af7ed92504ae: Waiting
# 94b8173c4f0e: Layer already exists
# c87f528e95da: Layer already exists
# 9e8fb042c730: Layer already exists
# 740a88dae04d: Layer already exists
# 6b655fdddf71: Layer already exists
# e1204abc6bc2: Layer already exists
# fa82d50f60b5: Layer already exists
# 687d8356d365: Layer already exists
# 26ddfcb7090e: Layer already exists
# d45fc2e9c061: Layer already exists
# ae39a55da88b: Layer already exists
# 7e907f0764b8: Layer already exists
# 8fac15dd911c: Layer already exists
# a001dd064a81: Layer already exists
# 94f8ff43aced: Layer already exists
# 29138effb439: Layer already exists
# 59808e8443ed: Layer already exists
# 982dbd99d0fd: Layer already exists
# dbfe8c01e73c: Layer already exists
# af7ed92504ae: Layer already exists
# latest: digest: sha256:09b2f3d499dc20e5bd06f86cf25a4ae96756c2d82a3ee039b8337d1361b4359c size: 4513
# 2022/09/11 15:35:30 Successfully pushed image: 20729af06f544124b7dd3c59794d2397.azurecr.io/azureml/azureml_5ef0227ccb95815183b084b36f0e8dc1:latest
# 2022/09/11 15:35:30 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 217.490496)
# 2022/09/11 15:35:30 Populating digests for step ID: acb_step_0...
# 2022/09/11 15:35:31 Successfully populated digests for step ID: acb_step_0
# 2022/09/11 15:35:31 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 100.897372)
# 2022/09/11 15:35:31 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 1.160829)
# 2022/09/11 15:35:31 The following dependencies were found:
# 2022/09/11 15:35:31
# - image:
#     registry: 20729af06f544124b7dd3c59794d2397.azurecr.io
#     repository: azureml/azureml_5ef0227ccb95815183b084b36f0e8dc1
#     tag: latest
#     digest: sha256:09b2f3d499dc20e5bd06f86cf25a4ae96756c2d82a3ee039b8337d1361b4359c
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi4.1.0-ubuntu20.04
#     tag: 20220729.v1
#     digest: sha256:86041abadd8cff9c2ed506b3477d45df5efa54f2adff0359d73cb825ab78510a
#   git: {}
# - image:
#     registry: 20729af06f544124b7dd3c59794d2397.azurecr.io
#     repository: azureml/azureml_5ef0227ccb95815183b084b36f0e8dc1
#     tag: "1"
#     digest: sha256:09b2f3d499dc20e5bd06f86cf25a4ae96756c2d82a3ee039b8337d1361b4359c
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi4.1.0-ubuntu20.04
#     tag: 20220729.v1
#     digest: sha256:86041abadd8cff9c2ed506b3477d45df5efa54f2adff0359d73cb825ab78510a
#   git: {}
#
#
# Run ID: cf1 was successful after 5m24s
#
# StepRun(Data Processing) Execution Summary
# ===========================================
# StepRun( Data Processing ) Status: Finished
# {'runId': 'ffa1ee7e-5d49-4f60-b29f-c612d6304b66', 'target': 'Compute-Cluster', 'status': 'Completed', 'startTimeUtc': '2022-09-11T15:41:55.580618Z', 'endTimeUtc': '2022-09-11T15:43:00.017653Z', 'services': {}, 'properties': {'ContentSnapshotId': '217d2ae6-6de9-4aa9-9d4d-a1d6865ea761', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'c2a2d3aa-eb4c-4de5-93af-ac26619c1dab', 'azureml.moduleName': 'Data Processing', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'def2c3e5', 'azureml.pipelinerunid': '1d4ca0c9-efb2-4842-b0b7-faa82a3d52f8', 'azureml.pipeline': '1d4ca0c9-efb2-4842-b0b7-faa82a3d52f8', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'amlctrain', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': 'ee03f8aa-5fb5-43e6-bcf6-a203dadec160'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'raw_data', 'mechanism': 'Direct'}}], 'outputDatasets': [], 'runDefinition': {'script': 'data_processing_script.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--datafolder', '$AZUREML_DATAREFERENCE_datafolder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'Compute-Cluster', 'dataReferences': {'datafolder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/ffa1ee7e-5d49-4f60-b29f-c612d6304b66/datafolder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {'raw_data': {'dataLocation': {'dataset': {'id': 'ee03f8aa-5fb5-43e6-bcf6-a203dadec160', 'name': None, 'version': '1'}, 'dataPath': None, 'uri': None, 'type': None}, 'mechanism': 'Direct', 'environmentVariableName': 'raw_data', 'pathOnCompute': None, 'overwrite': False, 'options': None}}, 'outputData': {}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'MyEnvironment', 'version': '1', 'assetId': 'azureml://locations/westus/workspaces/20729af0-6f54-4124-b7dd-3c59794d2397/environments/MyEnvironment/versions/1', 'autoRebuild': True, 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'name': 'project_environment', 'dependencies': ['python=3.8.13', {'pip': ['azureml-sdk']}, 'scikit-learn', 'pandas'], 'channels': ['anaconda', 'conda-forge']}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220729.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'sshPublicKeys': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMod ...
#
#
#
#
# StepRunId: d7a61ec0-27d2-441e-9028-c8ac8acd4316
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/d7a61ec0-27d2-441e-9028-c8ac8acd4316?wsid=/subscriptions/76d4f7e1-3c6a-41a3-968f-043a0cb83503/resourcegroups/azureml-sdk-rg/workspaces/azureml-sdk-ws&tid=aca956d5-1716-486c-9340-ffedc6d009ae
# StepRun( Model Training ) Status: Running
#
# StepRun(Model Training) Execution Summary
# ==========================================
# StepRun( Model Training ) Status: Finished
# {'runId': 'd7a61ec0-27d2-441e-9028-c8ac8acd4316', 'target': 'Compute-Cluster', 'status': 'Completed', 'startTimeUtc': '2022-09-11T15:43:07.212535Z', 'endTimeUtc': '2022-09-11T15:43:25.314427Z', 'services': {}, 'properties': {'ContentSnapshotId': '217d2ae6-6de9-4aa9-9d4d-a1d6865ea761', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '9c28d934-e8f3-4e19-a173-bf0ea8a87078', 'azureml.moduleName': 'Model Training', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '9f4de622', 'azureml.pipelinerunid': '1d4ca0c9-efb2-4842-b0b7-faa82a3d52f8', 'azureml.pipeline': '1d4ca0c9-efb2-4842-b0b7-faa82a3d52f8', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'amlctrain', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'model_training_script.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--datafolder', '$AZUREML_DATAREFERENCE_datafolder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'Compute-Cluster', 'dataReferences': {'datafolder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/ffa1ee7e-5d49-4f60-b29f-c612d6304b66/datafolder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'MyEnvironment', 'version': '1', 'assetId': 'azureml://locations/westus/workspaces/20729af0-6f54-4124-b7dd-3c59794d2397/environments/MyEnvironment/versions/1', 'autoRebuild': True, 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'name': 'project_environment', 'dependencies': ['python=3.8.13', {'pip': ['azureml-sdk']}, 'scikit-learn', 'pandas'], 'channels': ['anaconda', 'conda-forge']}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20220729.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'sshPublicKeys': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': False, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}, 'applicationEndpoints': {}, 'parameters': []}, 'logFiles': {'logs/azureml/executionlogs.txt' ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '1d4ca0c9-efb2-4842-b0b7-faa82a3d52f8', 'status': 'Completed', 'startTimeUtc': '2022-09-11T15:29:56.57721Z', 'endTimeUtc': '2022-09-11T15:43:26.436736Z', 'services': {}, 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}', 'azureml.continue_on_step_failure': 'False', 'azureml.continue_on_failed_optional_input': 'True', 'azureml.pipelineComponent': 'pipelinerun'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://azuremlsstoragec39dd682b.blob.core.windows.net/azureml/ExperimentRun/dcid.1d4ca0c9-efb2-4842-b0b7-faa82a3d52f8/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=berkl10oi4Pf5SWnfcCAnc28spMPy3jcnDWk8YH6hvA%3D&skoid=43194bf3-bde9-4af4-aff9-6ecdc2a6114c&sktid=aca956d5-1716-486c-9340-ffedc6d009ae&skt=2022-09-11T15%3A19%3A57Z&ske=2022-09-12T23%3A29%3A57Z&sks=b&skv=2019-07-07&st=2022-09-11T15%3A33%3A36Z&se=2022-09-11T23%3A43%3A36Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://azuremlsstoragec39dd682b.blob.core.windows.net/azureml/ExperimentRun/dcid.1d4ca0c9-efb2-4842-b0b7-faa82a3d52f8/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=%2FxmmLbrnGm2PLmCyeaA3RtvC%2BSJ0aE6v6EuHUP17uUg%3D&skoid=43194bf3-bde9-4af4-aff9-6ecdc2a6114c&sktid=aca956d5-1716-486c-9340-ffedc6d009ae&skt=2022-09-11T15%3A19%3A57Z&ske=2022-09-12T23%3A29%3A57Z&sks=b&skv=2019-07-07&st=2022-09-11T15%3A33%3A36Z&se=2022-09-11T23%3A43%3A36Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://azuremlsstoragec39dd682b.blob.core.windows.net/azureml/ExperimentRun/dcid.1d4ca0c9-efb2-4842-b0b7-faa82a3d52f8/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=768Fb%2BxWxW1tIVr6jwXs7maNwVE3a4agxE7hmy0hFgg%3D&skoid=43194bf3-bde9-4af4-aff9-6ecdc2a6114c&sktid=aca956d5-1716-486c-9340-ffedc6d009ae&skt=2022-09-11T15%3A19%3A57Z&ske=2022-09-12T23%3A29%3A57Z&sks=b&skv=2019-07-07&st=2022-09-11T15%3A33%3A36Z&se=2022-09-11T23%3A43%3A36Z&sp=r'}, 'submittedBy': 'Vijay Gadhave'}
# 'Finished'
